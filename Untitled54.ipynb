# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/1-GenAI-HandsOn/5-SentimentAnalysis-LLM
# !ls
# Out:
# /content/drive/MyDrive/1-GenAI-HandsOn/5-SentimentAnalysis-LLM
# amazon_alexa.tsv

# %%
import pandas as pd

data = pd.read_csv('amazon_alexa.tsv', sep='\t')
data.head(10)
# Out:
#    rating       date             variation  \
# 0       5  31-Jul-18      Charcoal Fabric
# 1       5  31-Jul-18      Charcoal Fabric
# 2       4  31-Jul-18        Walnut Finish
# 3       5  31-Jul-18      Charcoal Fabric
# 4       5  31-Jul-18      Charcoal Fabric
# 5       5  31-Jul-18  Heather Gray Fabric
# 6       3  31-Jul-18     Sandstone Fabric
# 7       5  31-Jul-18      Charcoal Fabric
# 8       5  30-Jul-18  Heather Gray Fabric
# 9       5  30-Jul-18  Heather Gray Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1
# 5  I received the echo as a gift. I needed anothe...         1
# 6  Without having a cellphone, I cannot use many ...         1
# 7  I think this is the 5th one I've purchased. I'...         1
# 8                                        looks great         1
# 9  Love it! I’ve listened to songs I haven’t hear...         1

# %%
mydata = data[['verified_reviews','feedback']]
mydata.columns = ['review','label']

mydata.head()
# Out:
#                                               review  label
# 0                                      Love my Echo!      1
# 1                                          Loved it!      1
# 2  Sometimes while playing a game, you can answer...      1
# 3  I have had a lot of fun with this thing. My 4 ...      1
# 4                                              Music      1

# %%
mydata.value_counts('label')
# Out:
# label
# 1    2893
# 0     257
# Name: count, dtype: int64

# %%
# Count the occurrences of each label
label_counts = mydata["label"].value_counts()

# Get the number of rows to drop from the majority class
rows_to_drop = label_counts.max() - label_counts.min()

# Drop rows from the majority class randomly
if rows_to_drop > 0:
   data_majority = mydata[mydata["label"] == 1]
   data_balanced = mydata.drop(data_majority.sample(rows_to_drop).index)
else:
   data_balanced = mydata.copy()

# Check the new class balance
print(data_balanced["label"].value_counts())
# Out:
# label
# 1    257
# 0    257
# Name: count, dtype: int64

# %%
import re
import pandas as pd

def clean_text(text):
  # Check if the input is a string
  if isinstance(text, str):
    # Remove special characters and punctuation
    text = re.sub(r"[^\w\s]", " ", text)

    # Remove single characters
    text = re.sub(r"\b[a-zA-Z]\b", " ", text)

    # Remove HTML tags
    text = re.sub(r"<[^>]*>", " ", text)

    # Lowercase the text
    text = text.lower()

    # Remove extra whitespace
    text = re.sub(r"\s+", " ", text)

    # Trim leading and trailing spaces
    text = text.strip()

    return text
  else:
    # Handle non-string inputs (e.g., convert to string or skip)
    # Here, we choose to convert to an empty string for demonstration.
    # Replace with your desired handling logic if needed.
    return ""

# Extract the review column as a list
reviews = data_balanced['review'].tolist()

# Clean the text in the list
cleaned_reviews = [clean_text(review) for review in reviews]

# Add the cleaned reviews as a new column to the DataFrame
data_balanced['clean_reviews'] = cleaned_reviews

# %%
data_balanced
# Out:
#                                                  review  label  \
# 7     I think this is the 5th one I've purchased. I'...      1
# 18    We love the size of the 2nd generation echo. S...      1
# 20    Love the Echo and how good the music sounds pl...      1
# 46    It's like Siri, in fact, Siri answers more acc...      0
# 53    The sound from this Echo 2nd Generation is phe...      1
# ...                                                 ...    ...
# 3096  The product sounded the same as the emoji spea...      0
# 3109  Easy to set up and connect with smart devices....      1
# 3133  I like having more Alexa devices in my house a...      1
# 3137                                    Very convenient      1
# 3146  Listening to music, searching locations, check...      1
#
#                                           clean_reviews
# 7     think this is the 5th one ve purchased working...
# 18    we love the size of the 2nd generation echo st...
# 20    love the echo and how good the music sounds pl...
# 46    it like siri in fact siri answers more accurat...
# 53    the sound from this echo 2nd generation is phe...
# ...                                                 ...
# 3096  the product sounded the same as the emoji spea...
# 3109  easy to set up and connect with smart devices ...
# 3133  like having more alexa devices in my house and...
# 3137                                    very convenient
# 3146  listening to music searching locations checkin...
#
# [514 rows x 3 columns]

# %%
import pandas as pd

# Assuming your DataFrame is called "df"
total_rows = len(data_balanced)
test_size = int(total_rows * 0.95)

# Randomly sample train_size rows for the training set
test_set = data_balanced.sample(test_size)

# Get the remaining rows for the test set
train_set = data_balanced.drop(test_set.index)

# %%
# !pip install -q -U google-generativeai

# %%
# Necessary packages
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Used to securely store your API key
from google.colab import userdata

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# %%time
response = model.generate_content("What is the meaning of life?")

to_markdown(response.text)
# Out:
# CPU times: user 137 ms, sys: 22.2 ms, total: 159 ms
# Wall time: 7.64 s
# > The meaning of life is a deep philosophical question that has been pondered by humans for centuries. There is no one definitive answer that is universally accepted, as the meaning of life can vary depending on individual beliefs, values, and experiences. However, there are several common themes that emerge when people explore this question:
# >
# > 1. Purpose and Fulfillment: Many people find meaning in life through finding a purpose or goal that they feel passionate about. This could involve pursuing a career, raising a family, contributing to a cause, or simply living a life that is true to oneself.
# >
# > 2. Relationships and Connections: Strong relationships with family, friends, and loved ones can bring a deep sense of meaning and joy to life. Having people to share experiences with, support each other, and create memories can make life feel richer and more worthwhile.
# >
# > 3. Contribution: Making a positive contribution to the world can give life a sense of purpose and significance. This could involve volunteering, working in a meaningful field, or simply being a kind and compassionate person.
# >
# > 4. Personal Growth and Development: The journey of personal growth and self-discovery can be deeply meaningful. As we learn new things, challenge ourselves, and develop our skills and talents, we not only improve our lives but also gain a deeper understanding of who we are and what we want from life.
# >
# > 5. Experiences and Moments: Life is made up of countless experiences, both big and small. Savoring these moments, appreciating the beauty of the world around us, and being fully present in our lives can bring a sense of meaning and fulfillment.
# >
# > 6. Legacy and Impact: For some people, the meaning of life is found in leaving a legacy or making an impact that will continue beyond their lifetime. This could involve raising children who will carry on their values, creating works of art or literature that will inspire others, or contributing to a cause that will benefit future generations.
# >
# > Ultimately, the meaning of life is unique to each individual and is something that we must each discover for ourselves. It is a journey of exploration, self-reflection, and personal growth that can lead to a life filled with purpose, fulfillment, and meaning.

# %%
test_set_sample = test_set.sample(20)

test_set_sample['pred_label'] = ''

test_set_sample
# Out:
#                                                  review  label  \
# 1240  I haven't figured out how to make or receive c...      0
# 2413  Menu doesn’t work. Says it can’t connect to am...      0
# 1870  Wonderful, still learning how to use. Had a he...      1
# 820   Has great sound and is very responsive my voic...      1
# 935                                  Like it to do more      1
# 1224                                            Love it      1
# 2267  Great ! It was the best decision ! Especially ...      1
# 2195  It still doesn’t work.  I bet if I call and le...      0
# 531   This is the worst Amazon purchase I have made....      0
# 806   Sound is terrible if u want good music too get...      0
# 2866                             The volume is very low      0
# 2558  For the price, the product is nice quality and...      0
# 2203                                   Netflix and Hulu      1
# 1640  I love this device.  I bought it simple so tha...      1
# 1845  Alread had Echos and Dots, but the ability to ...      1
# 2427  Great device, I'm cutting my cable and watchin...      1
# 2346                   amazon fire stick is amazing !!!      1
# 1069                                 Love my Echo Spot!      1
# 545                             Love it.  Great product      1
# 2666  We are still in the discovery phase, but so fa...      1
#
#                                           clean_reviews pred_label
# 1240  haven figured out how to make or receive calls...
# 2413  menu doesn work says it can connect to amazon ...
# 1870  wonderful still learning how to use had heck o...
# 820   has great sound and is very responsive my voic...
# 935                                  like it to do more
# 1224                                            love it
# 2267  great it was the best decision especially if y...
# 2195  it still doesn work bet if call and let them k...
# 531   this is the worst amazon purchase have made am...
# 806   sound is terrible if want good music too get bose
# 2866                             the volume is very low
# 2558  for the price the product is nice quality and ...
# 2203                                   netflix and hulu
# 1640  love this device bought it simple so that can ...
# 1845  alread had echos and dots but the ability to c...
# 2427  great device cutting my cable and watching the...
# 2346                       amazon fire stick is amazing
# 1069                                  love my echo spot
# 545                               love it great product
# 2666  we are still in the discovery phase but so far...

# %%
# Convert the DataFrame to JSON using the to_json() method

json_data = test_set_sample[['clean_reviews','pred_label']].to_json(orient='records')

# Print the JSON data
print(json_data)
# Out:
# [{"clean_reviews":"when we first received this product it was great however about week ago the device served up video advertisement around 10 30pm at night and scared myself and my family if you want to make sure you are protected and don allow video directly in your home the spot is not device that can keep you safe","pred_label":""},{"clean_reviews":"just think that it to darn confusing and there are parts that would try and just wouldn work just don like it not what thought it would be","pred_label":""},{"clean_reviews":"decided to buy smart door lock and decided on getting the echo plus to control it chose kwikset 888 because amazon said it was compatible and bought 2 dots while was at it and when posed the question somebody in the community said it will work with alexa what didn know was the wave lock and zigbee alexa hub weren compatible does any body know of lock that works seamlessly with echo plus if not guess my choices are 1 exchange the plus for regular echo and buy separate hub like wink 2 return the whole alexa system and get something else don want to just buy another hub to use along side my echo plus or ll be back here asking how to integrate two hubs the reason kept from buying smart systems up to this point is because was afraid they wouldn operate seamlessly and unfortunately only do enough research after something doesn work","pred_label":""},{"clean_reviews":"am having real difficulty working with the echo dot alexi is not very smart 9 out of 10 questions have asked get the 34 not sure 34 half the time am still asking the question and alexi is saying 34 not sure 34 the music is great and works well for that all in all so far it been very frustrating experience","pred_label":""},{"clean_reviews":"the echo dot disconnects from the speaker about 12 20 times day do not buy the refurbished product 2 stars for effort","pred_label":""},{"clean_reviews":"great buy","pred_label":""},{"clean_reviews":"it easy to set up and use there are new features and skills added all the time","pred_label":""},{"clean_reviews":"set up the echo dot and it worked for an hour and then died completely do not buy refurbished sent back for return the day after received","pred_label":""},{"clean_reviews":"love all of the things that it can do can play with it and learn from it","pred_label":""},{"clean_reviews":"the firestick we were sent doesn work at all voice remote won even turn on we did all the troubleshooting steps didn work contacted amazon they sent us new one with no remote no way to control it we gave up and got roku which works great","pred_label":""},{"clean_reviews":"bought the spot and loved it within months it started acting funny and would stop working called and they determined that it was overheating was told to unplug and technical support would call within 24 48 hours waited 48 hours without response and replied to email and was asked to wait week week goes by with absolutely no response so do the inline chat per instructions told to wait longer really unacceptable expected more from amazon find it funny how they always thank me for being prime member but when an issue arises cannot even get assistance","pred_label":""},{"clean_reviews":"not all that happy the speaker isn great and for some reason lot of times when play music it will start to make some weird noise and just stop my son has google home and it is much better","pred_label":""},{"clean_reviews":"great device features are awesome the interaction is fantastic home automation works perfect if you link up your accounts correctly my only issue is out of 4 echo shows 2 of them have been sent off for repair because of the screen glitching these are less than 3 months old and already having issues first repairs were sent off and they updated the firmware when got the device back nothing worked had to update to the newest firmware for it to work again then 2 weeks later the glitch starts up again love the show but getting really frustrated with the glitching","p ...

# %%
prompt = f"""
You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
Customer reviews are provided between three back ticks.
In your output, only return the Json code back as output - which is provided between three backticks.
Your task is to update predicted labels under 'pred_label' in the Json code.
Don't make any changes to Json code format, please.

```
{json_data}
```
"""

print(prompt)
# Out:
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
# Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
# Customer reviews are provided between three back ticks.
# In your output, only return the Json code back as output - which is provided between three backticks.
# Your task is to update predicted labels under 'pred_label' in the Json code.
# Don't make any changes to Json code format, please.
#
# ```
# [{"clean_reviews":"when we first received this product it was great however about week ago the device served up video advertisement around 10 30pm at night and scared myself and my family if you want to make sure you are protected and don allow video directly in your home the spot is not device that can keep you safe","pred_label":""},{"clean_reviews":"just think that it to darn confusing and there are parts that would try and just wouldn work just don like it not what thought it would be","pred_label":""},{"clean_reviews":"decided to buy smart door lock and decided on getting the echo plus to control it chose kwikset 888 because amazon said it was compatible and bought 2 dots while was at it and when posed the question somebody in the community said it will work with alexa what didn know was the wave lock and zigbee alexa hub weren compatible does any body know of lock that works seamlessly with echo plus if not guess my choices are 1 exchange the plus for regular echo and buy separate hub like wink 2 return the whole alexa system and get something else don want to just buy another hub to use along side my echo plus or ll be back here asking how to integrate two hubs the reason kept from buying smart systems up to this point is because was afraid they wouldn operate seamlessly and unfortunately only do enough research after something doesn work","pred_label":""},{"clean_reviews":"am having real difficulty working with the echo dot alexi is not very smart 9 out of 10 questions have asked get the 34 not sure 34 half the time am still asking the question and alexi is saying 34 not sure 34 the music is great and works well for that all in all so far it been very frustrating experience","pred_label":""},{"clean_reviews":"the echo dot disconnects from the speaker about 12 20 times day do not buy the refurbished product 2 stars for effort","pred_label":""},{"clean_reviews":"great buy","pred_label":""},{"clean_reviews":"it easy to set up and use there are new features and skills added all the time","pred_label":""},{"clean_reviews":"set up the echo dot and it worked for an hour and then died completely do not buy refurbished sent back for return the day after received","pred_label":""},{"clean_reviews":"love all of the things that it can do can play with it and learn from it","pred_label":""},{"clean_reviews":"the firestick we were sent doesn work at all voice remote won even turn on we did all the troubleshooting steps didn work contacted amazon they sent us new one with no remote no way to control it we gave up and got roku which works great","pred_label":""},{"clean_reviews":"bought the spot and loved it within months it started acting funny and would stop working called and they determined that it was overheating was told to unplug and technical support would call within 24 48 hours waited 48 hours without response and replied to email and was asked to wait week week goes by with absolutely no response so do the inline chat per instructions told to wait longer really unacceptable expected more from amazon find it funny how they always thank me for being prime member but when an issue arises cannot even get assistance","pred_label":""},{"clean_reviews":"not all that happy the speaker isn great and for some reason lot of times when play music it will start to make some weird noise and just stop my son has google home and it is much better","pred_label":""},{"clean_reviews":"great device features are awesome the interaction is fantastic home automation works perfect if you link up your accounts correctly my only issue is out of 4 echo shows 2 of them have been sent off for repair because of the screen glitching these are less than 3 months old and already having issues first repairs were sent off and they updated the firmware when got the device back nothing worked had to update to the newest firmware for it to work again then 2 weeks later the glitch starts up again love the show but getting really frustrated with the glitching","p ...
# ```

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# ```
# [{"clean_reviews":"when we first received this product it was great however about week ago the device served up video advertisement around 10 30pm at night and scared myself and my family if you want to make sure you are protected and don allow video directly in your home the spot is not device that can keep you safe","pred_label":0},{"clean_reviews":"just think that it to darn confusing and there are parts that would try and just wouldn work just don like it not what thought it would be","pred_label":0},{"clean_reviews":"decided to buy smart door lock and decided on getting the echo plus to control it chose kwikset 888 because amazon said it was compatible and bought 2 dots while was at it and when posed the question somebody in the community said it will work with alexa what didn know was the wave lock and zigbee alexa hub weren compatible does any body know of lock that works seamlessly with echo plus if not guess my choices are 1 exchange the plus for regular echo and buy separate hub like wink 2 return the whole alexa system and get something else don want to just buy another hub to use along side my echo plus or ll be back here asking how to integrate two hubs the reason kept from buying smart systems up to this point is because was afraid they wouldn operate seamlessly and unfortunately only do enough research after something doesn work","pred_label":0},{"clean_reviews":"am having real difficulty working with the echo dot alexi is not very smart 9 out of 10 questions have asked get the 34 not sure 34 half the time am still asking the question and alexi is saying 34 not sure 34 the music is great and works well for that all in all so far it been very frustrating experience","pred_label":0},{"clean_reviews":"the echo dot disconnects from the speaker about 12 20 times day do not buy the refurbished product 2 stars for effort","pred_label":0},{"clean_reviews":"great buy","pred_label":1},{"clean_reviews":"it easy to set up and use there are new features and skills added all the time","pred_label":1},{"clean_reviews":"set up the echo dot and it worked for an hour and then died completely do not buy refurbished sent back for return the day after received","pred_label":0},{"clean_reviews":"love all of the things that it can do can play with it and learn from it","pred_label":1},{"clean_reviews":"the firestick we were sent doesn work at all voice remote won even turn on we did all the troubleshooting steps didn work contacted amazon they sent us new one with no remote no way to control it we gave up and got roku which works great","pred_label":0},{"clean_reviews":"bought the spot and loved it within months it started acting funny and would stop working called and they determined that it was overheating was told to unplug and technical support would call within 24 48 hours waited 48 hours without response and replied to email and was asked to wait week week goes by with absolutely no response so do the inline chat per instructions told to wait longer really unacceptable expected more from amazon find it funny how they always thank me for being prime member but when an issue arises cannot even get assistance","pred_label":0},{"clean_reviews":"not all that happy the speaker isn great and for some reason lot of times when play music it will start to make some weird noise and just stop my son has google home and it is much better","pred_label":0},{"clean_reviews":"great device features are awesome the interaction is fantastic home automation works perfect if you link up your accounts correctly my only issue is out of 4 echo shows 2 of them have been sent off for repair because of the screen glitching these are less than 3 months old and already having issues first repairs were sent off and they updated the firmware when got the device back nothing worked had to update to the newest firmware for it to work again then 2 weeks later the glitch starts up again love the show but getting really frustrated with the glitching","pred_label":0 ...
# ```

# %%
import json

# Clean the data by stripping the backticks
json_data = response.text.strip("`")

# Load the cleaned data and convert to DataFrame
data = json.loads(json_data)
df_sample = pd.DataFrame(data)

df_sample
# Out:
#                                         clean_reviews  pred_label
# 0   when we first received this product it was gre...           0
# 1   just think that it to darn confusing and there...           0
# 2   decided to buy smart door lock and decided on ...           0
# 3   am having real difficulty working with the ech...           0
# 4   the echo dot disconnects from the speaker abou...           0
# 5                                           great buy           1
# 6   it easy to set up and use there are new featur...           1
# 7   set up the echo dot and it worked for an hour ...           0
# 8   love all of the things that it can do can play...           1
# 9   the firestick we were sent doesn work at all v...           0
# 10  bought the spot and loved it within months it ...           0
# 11  not all that happy the speaker isn great and f...           0
# 12  great device features are awesome the interact...           0
# 13  the sound from this echo 2nd generation is phe...           1
# 14                  use this to control my smart home           1
# 15  love this clock just have to tell it to set my...           1
# 16  great product highly recommend getting the sta...           1
# 17  would like to tell you that have reason to hat...           0
# 18       love it the coolest thing since sliced bread           1
# 19  fire hd does so much more over priced pair of ...           0

# %%
test_set_sample['pred_label'] = df_sample['pred_label'].values
test_set_sample
# Out:
#                                                  review  label  \
# 1147  When we first received this product, it was gr...      0
# 2150  I just think that it's to darn confusing. And ...      0
# 1814  I decided to buy smart door lock and decided o...      0
# 2665  I am having real difficulty working with the E...      0
# 544   The echo dot disconnects from the speaker abou...      0
# 442                                         A great buy      1
# 2638  It's easy to set up and use. There are new fea...      1
# 660   I set up the Echo Dot and it worked for an hou...      0
# 2623  I love all of the things that it can do. I can...      1
# 2309  The Firestick we were sent doesn’t work. At al...      0
# 1379  Bought the spot and loved it. Within months it...      0
# 2589  Not all that happy. The speaker isn’t great an...      0
# 1612  Great device, features are awesome, the intera...      0
# 53    The sound from this Echo 2nd Generation is phe...      1
# 1546               I use this to control my smart home.      1
# 1081  I love this clock, I just have to tell it to s...      1
# 1134  Great product! Highly recommend getting the st...      1
# 2021  I would like to tell you that I have a reason ...      0
# 1251     I love it the coolest thing since sliced bread      1
# 1540  Fire HD does so much more.  Over priced pair o...      0
#
#                                           clean_reviews  pred_label
# 1147  when we first received this product it was gre...           0
# 2150  just think that it to darn confusing and there...           0
# 1814  decided to buy smart door lock and decided on ...           0
# 2665  am having real difficulty working with the ech...           0
# 544   the echo dot disconnects from the speaker abou...           0
# 442                                           great buy           1
# 2638  it easy to set up and use there are new featur...           1
# 660   set up the echo dot and it worked for an hour ...           0
# 2623  love all of the things that it can do can play...           1
# 2309  the firestick we were sent doesn work at all v...           0
# 1379  bought the spot and loved it within months it ...           0
# 2589  not all that happy the speaker isn great and f...           0
# 1612  great device features are awesome the interact...           0
# 53    the sound from this echo 2nd generation is phe...           1
# 1546                  use this to control my smart home           1
# 1081  love this clock just have to tell it to set my...           1
# 1134  great product highly recommend getting the sta...           1
# 2021  would like to tell you that have reason to hat...           0
# 1251       love it the coolest thing since sliced bread           1
# 1540  fire hd does so much more over priced pair of ...           0

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix

y_true = test_set_sample["label"]
y_pred = test_set_sample["pred_label"]

confusion_matrix(y_true, y_pred)
# Out:
# array([[12,  0],
#        [ 0,  8]])

# %%
TP = 12  # True Positives
TN = 8   # True Negatives
FP = 0   # False Positives
FN = 0   # False Negatives

# Total instances
total_instances = TP + TN + FP + FN

# Calculate accuracy
accuracy = (TP + TN) / total_instances * 100

print(f"Accuracy: {accuracy}%")
# Out:
# Accuracy: 100.0%
